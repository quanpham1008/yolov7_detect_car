# %%
# %cd /content/drive/MyDrive/YOLOv7_detect
# !git clone https://github.com/WongKinYiu/yolov7

# %%
# %cd /content/drive/MyDrive/YOLOv7_detect/yolov7
# !pip install -r requirements.txt

# %%
# !mkdir pretrain
# %cd pretrain
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt

# %%
# %cd /content/drive/MyDrive/YOLOv7_detect/yolov7
# !mkdir test_images
# %cd test_images
# !wget https://media-cdn-v2.laodong.vn/Storage/NewsPortal/2020/10/14/845156/Lai-Xe-O-To-Chinh-Gi.jpg
# !wget https://butl.vn/wp-content/uploads/2017/08/kinh_nghiem_lai_xe_duong_dai.jpg

# %%
# %cd /content/drive/MyDrive/YOLOv7_detect/yolov7
# !python detect.py --weights pretrain/yolov7.pt --source test_images/Lai-Xe-O-To-Chinh-Gi.jpg

# %%
from IPython.display import Image, display
display(Image(filename="/content/drive/MyDrive/YOLOv7_detect/yolov7/runs/detect/exp/Lai-Xe-O-To-Chinh-Gi.jpg"))

# %%
# %cd /content/drive/MyDrive/YOLOv7_detect
# !mkdir data
# %cd data
# !unzip ../Vehicles-Dataset.zip

# %%
# %cd /content/drive/MyDrive/YOLOv7_detect/yolov7
# !python train.py --batch 8 --cfg cfg/training/yolov7.yaml --epochs 100 --data /content/drive/MyDrive/YOLOv7_detect/data/data.yaml --weights 'pretrain/yolov7.pt'

# %%
# %cd /content/drive/MyDrive/YOLOv7_detect/yolov7
# !python detect.py --weights runs/train/exp2/weights/best.pt --source /content/drive/MyDrive/YOLOv7_detect/data/test/images/00dea1edf14f09ab_jpg.rf.3f17c8790a68659d03b1939a59ccda80.jpg
# Out:
# /content/drive/MyDrive/YOLOv7_detect/yolov7
# Namespace(weights=['runs/train/exp2/weights/best.pt'], source='/content/drive/MyDrive/YOLOv7_detect/data/test/images/00dea1edf14f09ab_jpg.rf.3f17c8790a68659d03b1939a59ccda80.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-122-g3b41c2c torch 2.0.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
display(Image(filename="runs/detect/exp2/00dea1edf14f09ab_jpg.rf.3f17c8790a68659d03b1939a59ccda80.jpg"))

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --source /content/drive/MyDrive/YOLOv7_detect/data/test/images/fca5c9c8f0276eff_jpg.rf.e37fa19b7839f09970da3e8c72e6c58e.jpg
# Out:
# Namespace(weights=['runs/train/exp2/weights/best.pt'], source='/content/drive/MyDrive/YOLOv7_detect/data/test/images/fca5c9c8f0276eff_jpg.rf.e37fa19b7839f09970da3e8c72e6c58e.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-122-g3b41c2c torch 2.0.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
display(Image(filename="runs/detect/exp3/fca5c9c8f0276eff_jpg.rf.e37fa19b7839f09970da3e8c72e6c58e.jpg"))
